# %%
import datetime
import pandas as pd
import numpy as np
import json
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
# import pandas as pd
from config import CMC_API_KEY

# %% [markdown]
# # CMC API analysis

# %%
if 1:
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    params = {
      'start':'1',
      'limit':'5000',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': 'b5cb5deb-9a58-41d6-9895-3fa7442526b4',
    }
    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=params)
      data = json.loads(response.text)
      # with open('/DATA/harshit_2311ai52/tgBot/coinmarketcap.json', 'w') as f:
      #     json.dump(data, f, indent=2)
      print(data['data'])
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
json_df = pd.json_normalize(data['data'])

# %%
json_df
# Out:
#          id                                 name    symbol  \
# 0         1                              Bitcoin       BTC
# 1      1027                             Ethereum       ETH
# 2       825                          Tether USDt      USDT
# 3      1839                                  BNB       BNB
# 4      5426                               Solana       SOL
# ...     ...                                  ...       ...
# 4995  27682        VoldemortTrumpRobotnik-10Neko  ETHEREUM
# 4996  19923                        Stader MaticX    MATICX
# 4997  23230                                DOGGO     DOGGO
# 4998  30586                         Book of Pepe      BOPE
# 4999  29994  KeyOfLife Multichain Store Of Value       KOL
#
#                                      slug  num_market_pairs  \
# 0                                 bitcoin             11793
# 1                                ethereum              9471
# 2                                  tether            102148
# 3                                     bnb              2273
# 4                                  solana               776
# ...                                   ...               ...
# 4995        voldemorttrumprobotnik-10neko                 9
# 4996                        stader-maticx               109
# 4997                                doggo                16
# 4998                         book-of-pepe                 1
# 4999  keyoflife-multichain-store-of-value                11
#
#                     date_added  \
# 0     2010-07-13T00:00:00.000Z
# 1     2015-08-07T00:00:00.000Z
# 2     2015-02-25T00:00:00.000Z
# 3     2017-07-25T00:00:00.000Z
# 4     2020-04-10T00:00:00.000Z
# ...                        ...
# 4995  2023-07-25T06:02:33.000Z
# 4996  2022-05-04T03:14:45.000Z
# 4997  2023-01-13T11:19:57.000Z
# 4998  2024-04-12T07:18:57.000Z
# 4999  2024-03-20T09:42:15.000Z
#
#                                                    tags    max_supply  \
# 0     [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1     [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2     [stablecoin, asset-backed-stablecoin, avalanch...           NaN
# 3     [marketplace, centralized-exchange, payments, ...           NaN
# 4     [pos, platform, solana-ecosystem, cms-holdings...           NaN
# ...                                                 ...           ...
# 4995                                                 []           NaN
# 4996    [polygon-ecosystem, liquid-staking-derivatives]           NaN
# 4997                          [memes, doggone-doggerel]           NaN
# 4998                                            [memes]  4.098300e+11
# 4999  [store-of-value, collectibles-nfts, memes, sta...  5.000000e+07
#
#       circulating_supply         total_supply  ...  quote.USD.market_cap  \
# 0           1.977625e+07             19776253  ...          1.387640e+12
# 1           1.204092e+08     120409186.758921  ...          3.042170e+11
# 2           1.205728e+11  122337925860.643845  ...          1.204532e+11
# 3           1.441000e+08     144099958.299529  ...          8.354153e+10
# 4           4.707028e+08     587522462.937222  ...          7.926842e+10
# ...                  ...                  ...  ...                   ...
# 4995        0.000000e+00           1000000000  ...          0.000000e+00
# 4996        0.000000e+00      36402937.410564  ...          0.000000e+00
# 4997        0.000000e+00      100000000000000  ...          0.000000e+00
# 4998        0.000000e+00         409830000000  ...          0.000000e+00
# 4999        0.000000e+00       5411054.863132  ...          0.000000e+00
#
#       quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                            59.0424                        1.473507e+12
# 1                            12.9441                        3.042170e+11
# 2                             5.1251                        1.222165e+11
# 3                             3.5546                        8.354153e+10
# 4                             3.3775                        9.894137e+10
# ...                              ...                                 ...
# 4995                          0.0000                        5.115823e+05
# 4996                          0.0000                        1.323030e+07
# 4997                          0.0000                        3.938053e+05
# 4998                          0.0000                        1.773593e+05
# 4999                          0.0000                        3.954389e+07
#
#       quote.USD.tvl    quote.USD.last_updated  platform.id  \
# 0               NaN  2024-11-01T12:34:00.000Z          NaN
# 1               NaN  2024-11-01T12:34:00.000Z          NaN
# 2               NaN  2024-11-01T12:34:00.000Z       1027.0
# 3               NaN  2024-11-01T12:34:00.000Z          NaN
# 4               NaN  2024-11-01T12:34:00.000Z          NaN
# ...             ...                       ...          ...
# 4995            NaN  2024-11-01T12:34:00.000Z       1027.0
# 4996            NaN  2024-11-01T12:34:00.000Z       1027.0
# 4997            NaN  2024-11-01T12:34:00.000Z       5426.0
# 4998            NaN  2024-11-01T12:34:00.000Z       1027.0
# 4999            NaN  2024-11-01T12:34:00.000Z       1839.0
#
#                 platform.name  platform.symbol  platform.slug  \
# 0                         NaN              NaN            NaN
# 1                         NaN              NaN            NaN
# 2                    Ethereum              ETH       ethereum
# 3                         NaN              NaN            NaN
# 4                         NaN              NaN            NaN
# ...                       ...              ...            ...
# 4995                 Ethereum              ETH       ethereum
# 4996                 Ethereum              ETH       ethereum
# 4997                   Solana              SOL         solana
# 4998                 Ethereum              ETH       ethereum
# 4999  BNB Smart Chain (BEP20)              BNB            bnb
#
#                             platform.token_address
# 0                                              NaN
# 1                                              NaN
# 2       0xdac17f958d2ee523a2206206994597c13d831ec7
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 4995    0xc32db1d3282e872d98f6437d3bcfa57801ca6d5c
# 4996    0xf03a7eb46d01d9ecaa104558c732cf82f6b6b645
# 4997  Doggoyb1uHFJGFdHhJf8FKEBUMv58qo98CisWgeD7Ftk
# 4998    0x599955aa9fbc197a1b717d8da6a7012cafe70ab3
# 4999    0x5569eDD2e1535Be2003470b2663F2Ff77e83d27e
#
# [5000 rows x 36 columns]

# %%
df = pd.read_csv("/DATA/harshit_2311ai52/tgBot/csv_files/all_coins_daily_vol_and_perc.csv")

# %%
df['avg'] = (df.iloc[:, 4] + df.iloc[:, 6] + df.iloc[:, 8] + df.iloc[:, 10] + df.iloc[:, 12] + df.iloc[:, 14]+ df.iloc[:, 16]) / 7

# %%
df = json_df[['cmc_rank','name', 'symbol', 'quote.USD.volume_change_24h', 'quote.USD.percent_change_24h']]

# %%
df
# Out:
#       cmc_rank                                 name      coin         avg  \
# 0            1                              Bitcoin       BTC   17.649200
# 1            2                             Ethereum       ETH   19.464086
# 2            3                          Tether USDt      USDT   17.823829
# 3            4                                  BNB       BNB   14.218057
# 4            5                               Solana       SOL   15.640900
# ...        ...                                  ...       ...         ...
# 4995      4996        VoldemortTrumpRobotnik-10Neko  ETHEREUM    0.000000
# 4996      4997                        Stader MaticX    MATICX   17.943657
# 4997      4998                                DOGGO     DOGGO    0.000000
# 4998      4999                         Book of Pepe      BOPE  293.275843
# 4999      5000  KeyOfLife Multichain Store Of Value       KOL    0.000000
#
#       11nov24_vol  11nov24_perc  10nov24_vol  10nov24_perc  09nov24_vol  \
# 0         69.5825      9.607139     -12.9027      3.260185     -27.8387
# 1         32.4473      6.159658       2.0671      3.911162      -5.2022
# 2         36.9538      0.032084       4.4506      0.021666     -12.8412
# 3         28.5262      4.398312     -10.9279     -0.721061      44.0846
# 4         31.0023      6.550996      -9.9883      2.696393     -33.2158
# ...           ...           ...          ...           ...          ...
# 4995       0.0000      0.000000       0.0000      0.000000       0.0000
# 4996       0.0000      0.000000       0.0000      0.000000     -52.8078
# 4997       0.0000      0.000000       0.0000      0.000000       0.0000
# 4998       0.0000      0.000000     217.3901    -28.031304    1835.5408
# 4999       0.0000      0.000000       0.0000      0.000000       0.0000
#
#       09nov24_perc  ...  05nov24_vol  05nov24_perc  04nov24_vol  04nov24_perc  \
# 0         0.628412  ...      22.5184      2.282867      44.0665      1.020842
# 1         4.313681  ...      27.9780      0.339566      26.9067      0.882212
# 2        -0.036978  ...      19.9689      0.040631      32.9227     -0.037043
# 3         3.410980  ...       3.0757      1.811136       4.6989      0.859441
# 4        -0.614150  ...      16.4793      3.238934      37.0625      0.783956
# ...            ...  ...          ...           ...          ...           ...
# 4995      0.000000  ...       0.0000      0.000000       0.0000      0.000000
# 4996      1.544471  ...     127.1711      2.782372     -65.6524     -1.359189
# 4997      0.000000  ...       0.0000      0.000000       0.0000      0.000000
# 4998     64.530261  ...       0.0000      0.000000       0.0000      0.000000
# 4999      0.000000  ...       0.0000      0.000000       0.0000      0.000000
#
#       03nov24_vol  03nov24_perc  02nov24_vol  02nov24_perc  01nov24_vol  \
# 0         18.7129     -1.351005     -16.8401     -0.796797      24.8816
# 1         17.0304     -1.312463     -26.2615     -0.837774       9.7232
# 2         17.7458     -0.026430     -19.5248      0.120148      17.0840
# 3          6.4279     -2.062633     -12.9544     -1.053297       4.1710
# 4         37.7765     -1.386001     -11.1170     -1.222055      13.3575
# ...           ...           ...          ...           ...          ...
# 4995       0.0000      0.000000       0.0000      0.000000       0.0000
# 4996    1037.3967     -4.221361       0.0000      0.000000       0.0000
# 4997       0.0000      0.000000       0.0000      0.000000       0.0000
# 4998       0.0000      0.000000       0.0000      0.000000       0.0000
# 4999       0.0000      0.000000       0.0000      0.000000       0.0000
#
#       01nov24_perc
# 0         0.378134
# 1         0.229633
# 2         0.002899
# 3         0.587493
# 4         0.414041
# ...            ...
# 4995      0.000000
# 4996      0.000000
# 4997      0.000000
# 4998      0.000000
# 4999      0.000000
#
# [5000 rows x 24 columns]

# %%
# a = pd.to_datetime('today').strftime('%d_%b_%Y_')
col_name_like = datetime.datetime.now().strftime("%d%b%y_").lower()
col_name_like
###### IMP : Filter columns with names containing "26_Oct"
# filtered_df = df.filter(like="26_Oct")

# has_column = any(col_name_like in col for col in df.columns)

# print(has_column)
# df = df.rename(columns = {'quote.USD.volume_change_24h':a+'vol', 'quote.USD.percent_change_24h':a+'perc'})
# Out:
# '01nov24_'

# %%
df = df.rename(columns = {'quote.USD.volume_change_24h':col_name_like+'vol', 'quote.USD.percent_change_24h':col_name_like+'perc'})

# %%
df.to_csv('/DATA/harshit_2311ai52/tgBot/csv_files/all_coins_daily_vol_and_perc.csv', index = False)

# %%
col_name = a
df[col_name+'vol'] = 0.0
df[col_name+'perc'] = 0.0

# %%
df.loc[[df['coin']=='BTC' and df['name']=='Bitcoin']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 df.loc[[df['coin']=='BTC',df['name']=='Bitcoin']]
#
# File ~/anaconda3/envs/researchProj/lib/python3.12/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/envs/researchProj/lib/python3.12/site-packages/pandas/core/indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File ~/anaconda3/envs/researchProj/lib/python3.12/site-packages/pandas/core/indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File ~/anaconda3/envs/researchProj/lib/python3.12/site-packages/pandas/core/indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File ~/anaconda3/envs/researchProj/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/envs/researchProj/lib/python3.12/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([(True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, ...), (True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, ...)], dtype='object')] are in the [index]"

# %% [markdown]
# # Just some editing in csv's

# %%
analysis_csv = "/DATA/harshit_2311ai52/tgBot/csv_files/realtime_analysis.csv"
trades_csv = "/DATA/harshit_2311ai52/tgBot/csv_files/trades.csv"

df1 = pd.read_csv(analysis_csv)
df2= pd.read_csv(trades_csv)

df1= df1.merge(df2[['coin', 'remarks']], on='coin', how='left')

df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 7
#       4 df1 = pd.read_csv(analysis_csv)
#       5 df2= pd.read_csv(trades_csv)
# ----> 7 df1= df1.merge(df2[['coin', 'remarks']], on='coin', how='left')
#       9 df1
#
# File ~/anaconda3/envs/researchProj/lib/python3.12/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/envs/researchProj/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/envs/researchProj/lib/python3.12/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['remarks'] not in index"

# %%
for i in ["bh", "bk", "by", "ku", "ga"]:
    df_analysis[i+'_usd'] = df[i+"_size"]*df["curr_price"]

df_analysis
# Out:
#       coin  curr_price  infinite_supply  curr_supply_perc  24h_volume_change  \
# 0      TON    5.813996             True               NaN            -0.9231
# 1      SUI    1.748392            False         26.799637            97.9266
# 2     ORDI   39.387008            False        100.000000            84.5581
# 3    METIS   39.619567            False               NaN            66.7126
# 4   RENDER    6.536103            False               NaN           100.0088
# ..     ...         ...              ...               ...                ...
# 90     ALT    0.135290            False         22.324742           155.3528
# 91     MDT    0.048955            False               NaN           -18.3742
# 92  sample    0.000000            False          0.000000             0.0000
# 93     MNT    0.631899            False         52.527340            10.9784
# 94    ROSE    0.000000            False          0.000000             0.0000
#
#     24h_percent_change  7d_percent_change  30d_percent_change market_cap  \
# 0            -0.021784           3.286330            9.529858     14.74B
# 1             2.673355          14.944036          115.312426      4.69B
# 2             0.957190          17.041662           41.403293    827.13M
# 3            -2.463119           8.082487           24.075910    238.56M
# 4             1.441418           8.426312           28.197898      3.38B
# ..                 ...                ...                 ...        ...
# 90            9.495722          17.866651           72.237063    302.03M
# 91           -0.020560           4.857615           18.053306      33.1M
# 92            0.000000           0.000000            0.000000          0
# 93           -0.687266           0.448443            4.070928      2.06B
# 94            0.000000           0.000000            0.000000          0
#
#     bk_curr_profit  bh_curr_profit  by_curr_profit  ku_curr_profit   profit  \
# 0              NaN             NaN             NaN      233.742215  0.00000
# 1              NaN             NaN             NaN       74.839190  3.00000
# 2              NaN             NaN             NaN       43.225483  0.00000
# 3              NaN             NaN             NaN       13.198762  0.00000
# 4        45.246739             NaN             NaN             NaN  1.69536
# ..             ...             ...             ...             ...      ...
# 90             NaN             NaN             NaN             NaN  0.00000
# 91             NaN             NaN             NaN             NaN  0.00000
# 92             NaN             NaN             NaN             NaN  0.00000
# 93             NaN             NaN             NaN        5.316550  0.00000
# 94             NaN             NaN             NaN             NaN  0.00000
#
#                      remarks  bh_usd    bk_usd  by_usd     ku_usd  ga_usd
# 0                        NaN     0.0  0.000000     0.0   7.049470     0.0
# 1                        NaN     0.0  0.000000     0.0   8.741960     0.0
# 2                        NaN     0.0  0.000000     0.0  19.693504     0.0
# 3                        NaN     0.0  0.000000     0.0  19.809783     0.0
# 4   trade 5.5 5.1 4.8 SL-4.5     0.0  1.045777     0.0   0.000000     0.0
# ..                       ...     ...       ...     ...        ...     ...
# 90                       NaN     0.0  0.000000     0.0   0.000000     0.0
# 91                       NaN     0.0  0.000000     0.0   0.000000     0.0
# 92                       NaN     0.0  0.000000     0.0   0.000000     0.0
# 93                       NaN     0.0  0.000000     0.0   0.631899     0.0
# 94    trade 68 62 57 SL-5233     0.0  0.000000     0.0   0.000000     0.0
#
# [95 rows x 20 columns]

# %% [markdown]
# # Whale Buy/Sell Alert

# %%
f = open("/DATA/harshit_2311ai52/tgBot/WhaleExportTG.json")
j = json.load(f)

# %%
json_df = pd.json_normalize(j["messages"])

# %%
# json_df["date"].apply(lambda x: print(x[:7]))

# %%
# pd.json_normalize(json_df["text"])

def fun(x):
    if 'list' in str(type(x)):
        for i in x:
            if 'dict' in str(type(i)):
                print(i['text'])
            elif 'str' in str(type(i)):
                print(i)
    
#             # print(x[0])
       
# json_df['text'].apply(fun)

dff = dict()
d = {
    'coin': [],
    'buy': [],
    'sell' : []
}

for index, row in json_df.iterrows():
    
    if index >100:
        break
    month = row['date'][:7]
    if temp == month:
        
    temp = month
# Out:
# 2019-08
# 2019-08
# 2019-08
# 2019-08
# LSK/BTC[binance]
#
# Big Sell detected ð¨
# 371.28000000 LSK @ 0.00010740 BTC
# 2019-08
# LSK/BTC[binance]
#
# Big Sell detected ð¨
# 388.39000000 LSK @ 0.00010640 BTC
# 2019-08
# LSK/ETH[binance]
#
# Big Sell detected ð¨
# 49.16000000 LSK @ 0.00594800 ETH
# 2019-08
# LSK/ETH[binance]
#
# Big Sell detected ð¨
# 50.64000000 LSK @ 0.00594500 ETH
# 2019-08
# TNB/BTC[binance]
#
# Big Sell detected ð¨
# 187723.00000000 TNB @ 0.00000026 BTC
# 2019-08
# EVX/ETH[binance]
#
# Big Sell detected ð¨
# 1092.00000000 EVX @ 0.00267290 ETH
# 2019-08
# LEND/BTC[binance]
#
# Big Sell detected ð¨
# 127634.00000000 LEND @ 0.00000031 BTC
# 2019-08
# ZRX/BTC [Binance]
#
# Big Sell detected ð¨
# 10348.00000000 ZRX @ 0.00001652 BTC
# 2019-08
# ZRX/BTC [Binance]
#
# Big Sell detected ð¨
# 10348.00000000 ZRX @ 0.00001652 BTC
# 2019-08
# IOTA/USDT [Binance]
#
# Big Sell detected ð
# 26365.14000000 IOTA @ 0.26110000 USDT
# 2019-08
# AMB/ETH [Binance]
#
# Big Sell detected ð
# 988.00000000 AMB @ 0.00012475 ETH
# 2019-08
# FUN/ETH [Binance]
#
# Big Sell detected 🚨
# 11002.00000000 FUN @ 0.00001059 ETH
# 2019-08
# XMR/ETH [Binance]
#
# Big Sell detected 🚨
# 12.59 XMR @ 0.443 ETH
# 2019-08
# 2019-08
# 2019-08
# 2019-08
# 2019-08
# RDN/BTC [Binance]
#
# Big Sell detected 🚨
# 1,600 RDN @ 0.0000170 BTC
# Order size: 0.027216000000000004 BTC (0%)
# 24h Vol: 21.97168 BTC
# 2019-08
# CVC/ETH [Binance]
#
# Big Sell detected 🚨
# 11,001 CVC @ 0.000196 ETH
# Order size: 2.16 ETH (4.53%)
# 24h Vol: 47.64 ETH
# 2019-08
# CVC/BTC [Binance]
#
# Big Sell detected 🚨
# 5,349 CVC @ 0.00000352 BTC
# Order size: 0.0188 BTC (0.27%)
# 24h Vol: 7.10 BTC
# 2019-08
# CVC/BTC [Binance]
#
# Big Sell detected 🚨
# 5,652 CVC @ 0.00000352 BTC
# Order size: 0.0199 BTC (0.28%)
# 24h Vol: 7.10 BTC
# 2019-08
# POE/BTC [Binance]
#
# Big Sell detected 🚨
# 194,922 POE @ 0.000000210 BTC
# 💰Order size: 0.0409 BTC (
# 0.49%
# )
# 📊24h Vol: 8.28 BTC
# 2019-08
# AMB/ETH [Binance]
#
# Big Sell detected 🚨
# 1,150 AMB @ 0.000126 ETH
# 💰Order size: 0.144 ETH (
# 0.34%
# )
# 📊24h Vol: 42.24 ETH
# 2019-08
# NPXS/ETH [Binance]
#
# Big Sell detected 🚨
# 2,051,889 NPXS @ 0.00000227 ETH
# 💰Order size: 4.66 ETH (
# 0.21%
# )
# 📊24h Vol: 2,247 ETH
# 2019-08
# BNT/ETH [Binance]
#
# Big Sell detected 🚨
# 23.32 BNT @ 0.00214 ETH
# 💰Order size: 0.0498 ETH (
# 0.40%
# )
# 📊24h Vol: 12.53 ETH
# 2019-08
# XVG/BTC [Binance]
#
# Big Sell detected 🚨
# 68,718 XVG @ 0.000000420 BTC
# 💰Order size: 0.0289 BTC (
# 0.15%
# )
# 📊24h Vol: 19.14 BTC
# 2019-08
# VIA/BTC [Binance]
#
# Big Sell detected 🚨
# 283.80 VIA @ 0.0000253 BTC
# 💰Order size: 0.00718 BTC (
# 0.13%
# )
# 📊24h Vol: 5.46 BTC
# 2019-08
# SNT/BTC [Binance]
#
# Big Sell detected 🚨
# 9,532 SNT @ 0.00000171 BTC
# 💰Order size: 0.0163 BTC (
# 0.21%
# )
# 📊24h Vol: 7.71 BTC
# 2019-08
# 2019-08
# HOT/ETH [Binance]
#
# Big Buy detected 🚀
# 1,257,770 HOT @ 0.00000424 ETH
# 💰Order size: 5.33 ETH (
# 0.29%
# )
# 📊24h Vol: 1,838 ETH
# 2019-08
# HOT/USDT [Binance]
#
# Big Sell detected 🚨
# 1,257,298 HOT @ 0.000896 USDT
# 💰Order size: 1,126 USDT (
# 0.15%
# )
# 📊24h Vol: 738,500 USDT
# 2019-08
# HOT/BNB [Binance]
#
# Big Buy detected 🚀
# 103,009 HOT @ 0.0000297 BNB
# 💰Order size: 3.06 BNB (
# 0.14%
# )
# 📊24h Vol: 2,151 BNB
# 2019-08
# HOT/BNB [Binance]
#
# Big Buy detected 🚀
# 101,123 HOT @ 0.0000297 BNB
# 💰Order size: 3.00 BNB (
# 0.14%
# )
# 📊24h Vol: 2,151 BNB
# 2019-08
# HOT/ETH [Binance]
#
# Big Buy detected 🚀
# 1,192,111 HOT @ 0.00000425 ETH
# 💰Order size: 5.07 ETH (
# 0.28%
# )
# 📊24h Vol: 1,838 ETH
# 2019-08
# PPT/BTC [Binance]
#
# Big Sell detected 🚨
# 1,889 PPT @ 0.0000565 BTC
# 💰Order size: 0.107 BTC (
# 0.38%
# )
# 📊24h Vol: 27.96 BTC
# 2019-08
# CDT/ETH [Binance]
#
# Big Sell detected 🚨
# 10,771 CDT @ 0.0000864 ETH
# 💰Order size: 0.930 ETH (
# 0.13%
# )
# 📊24h Vol: 702.19 ETH
# 2019-08
# ENJ/BTC [Binance]
#
# Big Sell detected 🚨
# 13,900 ENJ @ 0.00000535 BTC
# 💰Order size: 0.0744 BTC (
# 0.10%
# )
# 📊24h Vol: 70.85 BTC
# 2019-08
# ALGO/USDC [Binance]
#
# Big Sell detected 🚨
# 260.80 ALGO @ 0.690 USDC
# 💰Order size: 179.95 USDC (
# 0.13%
# )
# 📊24h Vol: 141,007 USDC
# 2019-08
# ALGO/USDC [Binance]
#
# Big Sell detected 🚨
# 478.81 ALGO @ 0.690 USDC
# 💰Order size: 330.38 USDC (
# 0.23%
# )
# 📊24h Vol: 141,007 USDC
# 2019-08
# REQ/ETH [Binance]
#
# Big Sell detected 🚨
# 5,732 REQ @ 0.0000585 ETH
# 💰Order size: 0.335 ETH (
# 0.19%
# )
# 📊24h Vol: 172.54 ETH
# 2019-08
# 2019-08
# INS/BTC [Binance] 🚨
#
# Big
# Sell
#  detected 🔴
# 1,589 INS @ 0.0000195 BTC
# 💰Order size: 0.0310 BTC (
# 0.22%
# )
# 📊24h Vol: 13.78 BTC
# 2019-08
# INS/BTC [Binance] 🚨
#
# Big
# Sell
#  detected 🔴
# 1,942 INS @ 0.0000195 BTC
# 💰Order size: 0.0379 BTC (
# 0.27%
# )
# 📊24h Vol: 13.78 BTC
# 2019-08
# VIA/BTC [Binance] 🚨
#
# Big
# Sell
#  detected 🔴
# 402.31 VIA @ 0.0000250 BTC
# 💰Order size: 0.0101 BTC (
# 0.17%
# )
# 📊24h Vol: 5.96 BTC
# 2019-08
# HOT/ETH [Binance] 🚨
#
# Big
# Sell
#  detected 🔴
# 1,417,077 HOT @ 0.00000423 ETH
# 💰Order size: 5.99 ETH (
# 0.27%
# )
# 📊24h Vol: 2,200 ETH
# 2019-08
# HOT/BNB [Binance] 🚨
#
# Big
# Sell
#  detected 🔴
# 282,475 HOT @ 0.0000296 BNB
# 💰Order size: 8.37 BNB (
# 0.36%
# )
# 📊24h Vol: 2,334 BNB
# 2019-08
# HOT/BNB [Binance] 🚨
#
# Big
# Sell
#  detected 🔴
# 603,901 HOT @ 0.0000296 BNB
# 💰Order size: 17.87 BNB (
# 0.77%
# )
# 📊24h Vol: 2,334 BNB
# 2019-08
# HOT/BNB [Binance] 🚨
#
# Big
# Sell
#  detected 🔴
# 119,543 HOT @ 0.0000296 BNB
# 💰Order size: 3.53 BNB (
# 0.15%
# )
# 📊24h Vol: 2,334 BNB
# 2019-08
# VIA/BTC [Binance] 🚨
#
# Big
# Sell
#  detected 🔴
# 384.66 VIA @ 0.0000250 BTC
# 💰Order size: 0.00962 BTC (
# 0.16%
# )
# 📊24h Vol: 5.96 BTC
# 2019-08
# ALGO/USDC [Binance] 🚨
#
# Big
# Sell
#  detected 🔴
# 539.63 ALGO @ 0.688 USDC
# 💰Order size: 371.27 USDC (
# 0.25%
# )
# 📊24h Vol: 146,254 USDC
# 2019-08
# CELR/BTC [Binance] 🚨
#
# Big
# Sell
#  detected 🔴
# 167,552 CELR @ 0.000000690 BTC
# 💰Order size: 0.116 BTC (
# 0.17%
# )
# 📊24h Vol: 69.12 BTC
# 2019-08
# ETH/TUSD [Binance]
#
# Big
# Buy
#  detected ✳
# 4.50 ETH @ 210.07 TUSD
# 💰Order size: 945.31 TUSD (
# 0.12%
# )
# 📊24h Vol: 798,350 TUSD
# 2019-08
# GTO/TUSD [Binance]
#
# Big
# Sell
#  detected 🔴
# 1,865 GTO @ 0.0149 TUSD
# 💰Order size: 27.81 TUSD (
# 1.71%
# )
# 📊24h Vol: 1,629 TUSD
# 2019-08
# OMG/BTC [Binance]
#
# Big
# Buy
#  detected ✳
# 519.22 OMG @ 0.000113 BTC
# 💰Order size: 0.0587 BTC (
# 0.21%
# )
# 📊24h Vol: 28.59 BTC
# 2019-08
# 2019-08
# RCN/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 5,087 RCN @ 0.000535 BNB
# 💰Order size: 2.72 BNB (
# 8.19%
# )
# 📊24h Vol: 33.25 BNB
# 2019-08
# GNT/ETH [Binance]
#
# Big
# Buy
#  detected ✳
# 29,336 GNT @ 0.000276 ETH
# 💰Order size: 8.11 ETH (
# 9.66%
# )
# 📊24h Vol: 83.94 ETH
# 2019-08
# GNT/ETH [Binance]
#
# Big
# Buy
#  detected ✳
# 17,490 GNT @ 0.000277 ETH
# 💰Order size: 4.85 ETH (
# 5.78%
# )
# 📊24h Vol: 83.94 ETH
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Buy
#  detected ✳
# 3,409 GNT @ 0.00197 BNB
# 💰Order size: 6.72 BNB (
# 21.86%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Buy
#  detected ✳
# 3,077 GNT @ 0.00197 BNB
# 💰Order size: 6.07 BNB (
# 19.73%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Buy
#  detected ✳
# 4,682 GNT @ 0.00203 BNB
# 💰Order size: 9.50 BNB (
# 30.89%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Buy
#  detected ✳
# 4,682 GNT @ 0.00203 BNB
# 💰Order size: 9.50 BNB (
# 30.89%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Buy
#  detected ✳
# 28,418 GNT @ 0.00203 BNB
# 💰Order size: 57.66 BNB (
# 187.49%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Buy
#  detected ✳
# 4,680 GNT @ 0.00203 BNB
# 💰Order size: 9.50 BNB (
# 30.88%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Buy
#  detected ✳
# 1,612 GNT @ 0.00231 BNB
# 💰Order size: 3.73 BNB (
# 12.13%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Buy
#  detected ✳
# 12,271 GNT @ 0.00231 BNB
# 💰Order size: 28.40 BNB (
# 92.33%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Buy
#  detected ✳
# 3,644 GNT @ 0.00231 BNB
# 💰Order size: 8.43 BNB (
# 27.42%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 5,499 GNT @ 0.00204 BNB
# 💰Order size: 11.21 BNB (
# 36.44%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# CVC/BNB [Binance]
#
# Big
# Buy
#  detected ✳
# 2,228 CVC @ 0.00142 BNB
# 💰Order size: 3.16 BNB (
# 16.19%
# )
# 📊24h Vol: 19.53 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 28,151 GNT @ 0.00204 BNB
# 💰Order size: 57.37 BNB (
# 186.55%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 2,726 GNT @ 0.00204 BNB
# 💰Order size: 5.56 BNB (
# 18.09%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 5,282 GNT @ 0.00204 BNB
# 💰Order size: 10.78 BNB (
# 35.05%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 2,194 GNT @ 0.00204 BNB
# 💰Order size: 4.48 BNB (
# 14.56%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 1,921 GNT @ 0.00204 BNB
# 💰Order size: 3.92 BNB (
# 12.76%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 937.00 GNT @ 0.00204 BNB
# 💰Order size: 1.91 BNB (
# 6.22%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 933.00 GNT @ 0.00205 BNB
# 💰Order size: 1.91 BNB (
# 6.22%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Buy
#  detected ✳
# 2,356 GNT @ 0.00214 BNB
# 💰Order size: 5.05 BNB (
# 16.42%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Buy
#  detected ✳
# 735.00 GNT @ 0.00214 BNB
# 💰Order size: 1.58 BNB (
# 5.12%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 870.00 GNT @ 0.00216 BNB
# 💰Order size: 1.88 BNB (
# 6.11%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# MTH/ETH [Binance]
#
# Big
# Sell
#  detected 🔴
# 36,726 MTH @ 0.0000576 ETH
# 💰Order size: 2.11 ETH (
# 6.20%
# )
# 📊24h Vol: 34.08 ETH
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 2,000 GNT @ 0.00215 BNB
# 💰Order size: 4.30 BNB (
# 13.98%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 2,375 GNT @ 0.00208 BNB
# 💰Order size: 4.93 BNB (
# 16.03%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 1,716 GNT @ 0.00208 BNB
# 💰Order size: 3.57 BNB (
# 11.59%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 3,108 GNT @ 0.00208 BNB
# 💰Order size: 6.46 BNB (
# 21.00%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Buy
#  detected ✳
# 3,108 GNT @ 0.00208 BNB
# 💰Order size: 6.46 BNB (
# 21.00%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Buy
#  detected ✳
# 3,092 GNT @ 0.00205 BNB
# 💰Order size: 6.32 BNB (
# 20.56%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/ETH [Binance]
#
# Big
# Sell
#  detected 🔴
# 15,007 GNT @ 0.000295 ETH
# 💰Order size: 4.43 ETH (
# 5.28%
# )
# 📊24h Vol: 83.94 ETH
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 1,165 GNT @ 0.00199 BNB
# 💰Order size: 2.32 BNB (
# 7.53%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 2,631 GNT @ 0.00199 BNB
# 💰Order size: 5.23 BNB (
# 16.99%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 885.00 GNT @ 0.00199 BNB
# 💰Order size: 1.76 BNB (
# 5.72%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# GNT/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 876.00 GNT @ 0.00199 BNB
# 💰Order size: 1.74 BNB (
# 5.66%
# )
# 📊24h Vol: 30.75 BNB
# 2019-08
# NCASH/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 70,308 NCASH @ 0.0000406 BNB
# 💰Order size: 2.85 BNB (
# 6.01%
# )
# 📊24h Vol: 47.46 BNB
# 2019-08
# NCASH/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 100,857 NCASH @ 0.0000406 BNB
# 💰Order size: 4.09 BNB (
# 8.63%
# )
# 📊24h Vol: 47.46 BNB
# 2019-08
# NEBL/BNB [Binance]
#
# Big
# Sell
#  detected 🔴
# 156.50 NEBL @ 0.0195 BNB
# 💰Order size: 3.05 BNB (
# 6.54%
# )
# 📊24h Vol: 46.72 BNB
# 2019-08
# NEBL/BNB [Binance]
#
# Big
# Buy
#  detected ✳
# 430.30 NEBL @ 0.0195 BNB
# 💰Order size: 8.40 BNB (
# 17.98%
# )
# 📊24h Vol: 46.72 BNB
# 2019-08
# STORM/BTC [Binance]
#
# Big
# Buy
#  detected ✳
# 54,893 STORM @ 0.000000150 BTC
# 💰Order size: 0.00823 BTC (
# 0.18%
# )
# 📊24h Vol: 4.51 BTC
# 2019-08
# POWR/BTC [Binance]
#
# Big
# Sell
#  detected 🔴
# 7,575 POWR @ 0.00000534 BTC
# 💰Order size: 0.0405 BTC (
# 0.67%
# )
# 📊24h Vol: 6.06 BTC
# 2019-08
# KEY/BTC [Binance]
#
# Big
# Sell
#  detected 🔴
# 328,127 KEY @ 0.000000150 BTC
# 💰Order size: 0.0492 BTC (
# 0.50%
# )
# 📊24h Vol: 9.77 BTC

# %% [markdown]
# # Liquidation Alert
